# %%
import os
import math
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
import time

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split

from torchvision.datasets import CIFAR10

from model_architecture import *

# %% [markdown]
# # Dataset preparation

# %%
def get_dataset(train_val_split = 0.9):

    transform  = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ])
    
    train_data = CIFAR10(root='./data', train = True, download = first_run, transform = transform)
    test_data  = CIFAR10(root='./data', train = False, download = first_run, transform = transform)

    train_size = int(train_val_split * len(train_data))
    val_size = len(train_data) - train_size


    train_data, val_data = random_split(train_data, [train_size, val_size])
    
    return train_data, val_data, test_data


def get_dataloader(batch_size, train_val_split = 0.9, num_workers = 1):
    
    train_set, val_set, test_set = get_dataset(train_val_split)
    trainloader = DataLoader(train_set, batch_size = batch_size, shuffle = True, num_workers = num_workers, pin_memory = True)
    valloader = DataLoader(val_set, batch_size = batch_size, shuffle = False, num_workers = num_workers, pin_memory = True)
    testloader = DataLoader(test_set, batch_size = batch_size, shuffle = False, num_workers = num_workers, pin_memory = True)

    return trainloader, valloader, testloader

# %% [markdown]
# # k = 12, depth = 40

# %%
growth_rate = 12
depth = 40 
reduction = 0.5
num_classes = 10
bottle_neck_flag = True
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "sparse"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(36, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(36, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(36, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(36, 18, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(18, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(30, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(42, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(42, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(36, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(36, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(36, 18, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(18, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(30, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(42, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(42, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(36, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(36, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=36, out_features=10, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 0.1242M

# %%
batch_size = 32
epochs = 70
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'sparsenet_cifar10_k12_depth40')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 1.624018 | Validation Accuracy: 51.58% | Time elapsed: 34.66s
# Epoch 2 | Training Loss (Avg): 1.134922 | Validation Accuracy: 65.3% | Time elapsed: 35.17s
# Epoch 3 | Training Loss (Avg): 0.911614 | Validation Accuracy: 68.3% | Time elapsed: 35.93s
# Epoch 4 | Training Loss (Avg): 0.784496 | Validation Accuracy: 72.04% | Time elapsed: 37.33s
# Epoch 5 | Training Loss (Avg): 0.699037 | Validation Accuracy: 74.5% | Time elapsed: 35.78s
# Epoch 6 | Training Loss (Avg): 0.646905 | Validation Accuracy: 75.08% | Time elapsed: 35.89s
# Epoch 7 | Training Loss (Avg): 0.601672 | Validation Accuracy: 75.98% | Time elapsed: 34.31s
# Epoch 8 | Training Loss (Avg): 0.558173 | Validation Accuracy: 78.18% | Time elapsed: 34.97s
# Epoch 9 | Training Loss (Avg): 0.522528 | Validation Accuracy: 78.14% | Time elapsed: 33.93s
# Epoch 10 | Training Loss (Avg): 0.500297 | Validation Accuracy: 79.7% | Time elapsed: 34.94s
# Epoch 11 | Training Loss (Avg): 0.472686 | Validation Accuracy: 80.22% | Time elapsed: 36.41s
# Epoch 12 | Training Loss (Avg): 0.449480 | Validation Accuracy: 78.92% | Time elapsed: 35.44s
# Epoch 13 | Training Loss (Avg): 0.422224 | Validation Accuracy: 80.4% | Time elapsed: 36.40s
# Epoch 14 | Training Loss (Avg): 0.411653 | Validation Accuracy: 80.98% | Time elapsed: 35.20s
# Epoch 15 | Training Loss (Avg): 0.395327 | Validation Accuracy: 80.96% | Time elapsed: 34.84s
# Epoch 16 | Training Loss (Avg): 0.368611 | Validation Accuracy: 80.04% | Time elapsed: 35.10s
# Epoch 17 | Training Loss (Avg): 0.357669 | Validation Accuracy: 81.44% | Time elapsed: 36.27s
# Epoch 18 | Training Loss (Avg): 0.339959 | Validation Accuracy: 79.76% | Time elapsed: 34.94s
# Epoch 19 | Training Loss (Avg): 0.323205 | Validation Accuracy: 79.1% | Time elapsed: 35.99s
# Epoch 20 | Training Loss (Avg): 0.314540 | Validation Accuracy: 81.3% | Time elapsed: 36.27s
# Epoch 21 | Training Loss (Avg): 0.305022 | Validation Accuracy: 81.7% | Time elapsed: 36.50s
# Epoch 22 | Training Loss (Avg): 0.296108 | Validation Accuracy: 81.76% | Time elapsed: 36.29s
# Epoch 23 | Training Loss (Avg): 0.279561 | Validation Accuracy: 81.94% | Time elapsed: 35.26s
# Epoch 24 | Training Loss (Avg): 0.267246 | Validation Accuracy: 82.7% | Time elapsed: 36.34s
# Epoch 25 | Training Loss (Avg): 0.262345 | Validation Accuracy: 81.92% | Time elapsed: 34.65s
# Epoch 26 | Training Loss (Avg): 0.251593 | Validation Accuracy: 81.48% | Time elapsed: 35.21s
# Epoch 27 | Training Loss (Avg): 0.246279 | Validation Accuracy: 81.44% | Time elapsed: 35.55s
# Epoch 28 | Training Loss (Avg): 0.227885 | Validation Accuracy: 82.54% | Time elapsed: 34.35s
# Epoch 29 | Training Loss (Avg): 0.225241 | Validation Accuracy: 82.26% | Time elapsed: 35.75s
# Epoch 30 | Training Loss (Avg): 0.211845 | Validation Accuracy: 81.72% | Time elapsed: 35.67s
# Epoch 31 | Training Loss (Avg): 0.208009 | Validation Accuracy: 82.5% | Time elapsed: 34.87s
# Epoch 32 | Training Loss (Avg): 0.200709 | Validation Accuracy: 82.3% | Time elapsed: 35.47s
# Epoch 33 | Training Loss (Avg): 0.197034 | Validation Accuracy: 82.42% | Time elapsed: 37.64s
# Epoch 34 | Training Loss (Avg): 0.185542 | Validation Accuracy: 82.26% | Time elapsed: 35.35s
# Epoch 35 | Training Loss (Avg): 0.181202 | Validation Accuracy: 82.5% | Time elapsed: 36.04s
# Epoch 36 | Training Loss (Avg): 0.172399 | Validation Accuracy: 82.02% | Time elapsed: 36.04s
# Epoch 37 | Training Loss (Avg): 0.163916 | Validation Accuracy: 82.66% | Time elapsed: 35.16s
# Epoch 38 | Training Loss (Avg): 0.168131 | Validation Accuracy: 81.92% | Time elapsed: 35.36s
# Epoch 39 | Training Loss (Avg): 0.153440 | Validation Accuracy: 80.94% | Time elapsed: 37.04s
# Epoch 40 | Training Loss (Avg): 0.152726 | Validation Accuracy: 82.56% | Time elapsed: 37.78s
# Epoch 41 | Training Loss (Avg): 0.144986 | Validation Accuracy: 81.74% | Time elapsed: 35.21s
# Epoch 42 | Training Loss (Avg): 0.151483 | Validation Accuracy: 81.28% | Time elapsed: 35.23s
# Epoch 43 | Training Loss (Avg): 0.134687 | Validation Accuracy: 81.86% | Time elapsed: 34.96s
# Epoch 44 | Training Loss (Avg): 0.129168 | Validation Accuracy: 80.1% | Time elapsed: 34.92s
# Epoch 45 | Training Loss (Avg): 0.135379 | Validation Accuracy: 82.96% | Time elapsed: 36.60s
# Epoch 46 | Training Loss (Avg): 0.124674 | Validation Accuracy: 83.08% | Time elapsed: 34.97s
# Epoch 47 | Training Loss (Avg): 0.121111 | Validation Accuracy: 81.66% | Time elapsed: 35.66s
# Epoch 48 | Training Loss (Avg): 0.116961 | Validation Accuracy: 82.7% | Time elapsed: 35.59s
# Epoch 49 | Training Loss (Avg): 0.108352 | Validation Accuracy: 83.56% | Time elapsed: 37.84s
# Epoch 50 | Training Loss (Avg): 0.114304 | Validation Accuracy: 82.86% | Time elapsed: 36.31s
# Epoch 51 | Training Loss (Avg): 0.114091 | Validation Accuracy: 82.78% | Time elapsed: 36.55s
# Epoch 52 | Training Loss (Avg): 0.103262 | Validation Accuracy: 82.64% | Time elapsed: 36.31s
# Epoch 53 | Training Loss (Avg): 0.107345 | Validation Accuracy: 82.82% | Time elapsed: 37.17s
# Epoch 54 | Training Loss (Avg): 0.101775 | Validation Accuracy: 80.66% | Time elapsed: 35.65s
# Epoch 55 | Training Loss (Avg): 0.096807 | Validation Accuracy: 82.22% | Time elapsed: 35.75s
# Epoch 56 | Training Loss (Avg): 0.100587 | Validation Accuracy: 82.78% | Time elapsed: 35.60s
# Epoch 57 | Training Loss (Avg): 0.089078 | Validation Accuracy: 82.76% | Time elapsed: 35.83s
# Epoch 58 | Training Loss (Avg): 0.101281 | Validation Accuracy: 82.68% | Time elapsed: 36.09s
# Epoch 59 | Training Loss (Avg): 0.081632 | Validation Accuracy: 82.98% | Time elapsed: 35.68s
# Epoch 60 | Training Loss (Avg): 0.081917 | Validation Accuracy: 82.58% | Time elapsed: 35.08s
# Epoch 61 | Training Loss (Avg): 0.083405 | Validation Accuracy: 82.44% | Time elapsed: 35.89s
# Epoch 62 | Training Loss (Avg): 0.074406 | Validation Accuracy: 83.2% | Time elapsed: 36.06s
# Epoch 63 | Training Loss (Avg): 0.080454 | Validation Accuracy: 82.9% | Time elapsed: 37.04s
# Epoch 64 | Training Loss (Avg): 0.072129 | Validation Accuracy: 83.42% | Time elapsed: 36.59s
# Epoch 65 | Training Loss (Avg): 0.078992 | Validation Accuracy: 83.24% | Time elapsed: 36.35s
# Epoch 66 | Training Loss (Avg): 0.073695 | Validation Accuracy: 83.12% | Time elapsed: 35.28s
# Epoch 67 | Training Loss (Avg): 0.065258 | Validation Accuracy: 82.22% | Time elapsed: 35.34s
# Epoch 68 | Training Loss (Avg): 0.067732 | Validation Accuracy: 82.52% | Time elapsed: 35.38s
# Epoch 69 | Training Loss (Avg): 0.071273 | Validation Accuracy: 82.96% | Time elapsed: 36.23s
# Epoch 70 | Training Loss (Avg): 0.074504 | Validation Accuracy: 83.24% | Time elapsed: 36.06s
# Training Complete.

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 83.0%

# %% [markdown]
# # k = 24, depth = 100

# %%
growth_rate = 24
depth = 100
reduction = 0.5
num_classes = 10
bottle_neck_flag = True
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "sparse"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(120, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(60, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(84, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(132, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(156, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(120, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(60, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(84, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(132, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(156, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=120, out_features=10, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 1.4378M

# %%
batch_size = 32
epochs = 70
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'sparsenet_cifar10_k24_depth100')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 1.596949 | Validation Accuracy: 53.1% | Time elapsed: 135.34s
# Epoch 2 | Training Loss (Avg): 1.054401 | Validation Accuracy: 66.44% | Time elapsed: 135.32s
# Epoch 3 | Training Loss (Avg): 0.772946 | Validation Accuracy: 75.08% | Time elapsed: 135.19s
# Epoch 4 | Training Loss (Avg): 0.625315 | Validation Accuracy: 78.38% | Time elapsed: 135.30s
# Epoch 5 | Training Loss (Avg): 0.518316 | Validation Accuracy: 79.48% | Time elapsed: 135.13s
# Epoch 6 | Training Loss (Avg): 0.451553 | Validation Accuracy: 80.62% | Time elapsed: 134.95s
# Epoch 7 | Training Loss (Avg): 0.393580 | Validation Accuracy: 81.78% | Time elapsed: 135.21s
# Epoch 8 | Training Loss (Avg): 0.343305 | Validation Accuracy: 83.02% | Time elapsed: 135.02s
# Epoch 9 | Training Loss (Avg): 0.308969 | Validation Accuracy: 82.8% | Time elapsed: 135.58s
# Epoch 10 | Training Loss (Avg): 0.266628 | Validation Accuracy: 83.4% | Time elapsed: 135.31s
# Epoch 11 | Training Loss (Avg): 0.238872 | Validation Accuracy: 82.18% | Time elapsed: 135.20s
# Epoch 12 | Training Loss (Avg): 0.215140 | Validation Accuracy: 84.48% | Time elapsed: 135.55s
# Epoch 13 | Training Loss (Avg): 0.190680 | Validation Accuracy: 84.24% | Time elapsed: 135.13s
# Epoch 14 | Training Loss (Avg): 0.167745 | Validation Accuracy: 84.5% | Time elapsed: 135.54s
# Epoch 15 | Training Loss (Avg): 0.149958 | Validation Accuracy: 83.72% | Time elapsed: 135.21s
# Epoch 16 | Training Loss (Avg): 0.144174 | Validation Accuracy: 84.16% | Time elapsed: 135.74s
# Epoch 17 | Training Loss (Avg): 0.122754 | Validation Accuracy: 85.06% | Time elapsed: 135.16s
# Epoch 18 | Training Loss (Avg): 0.114093 | Validation Accuracy: 84.62% | Time elapsed: 135.38s
# Epoch 19 | Training Loss (Avg): 0.101679 | Validation Accuracy: 84.84% | Time elapsed: 135.45s
# Epoch 20 | Training Loss (Avg): 0.093971 | Validation Accuracy: 84.64% | Time elapsed: 135.24s
# Epoch 21 | Training Loss (Avg): 0.086812 | Validation Accuracy: 86.04% | Time elapsed: 135.12s
# Epoch 22 | Training Loss (Avg): 0.085017 | Validation Accuracy: 84.98% | Time elapsed: 134.88s
# Epoch 23 | Training Loss (Avg): 0.066164 | Validation Accuracy: 85.94% | Time elapsed: 134.65s
# Epoch 24 | Training Loss (Avg): 0.069810 | Validation Accuracy: 85.32% | Time elapsed: 134.45s
# Epoch 25 | Training Loss (Avg): 0.069231 | Validation Accuracy: 85.9% | Time elapsed: 134.57s
# Epoch 26 | Training Loss (Avg): 0.054013 | Validation Accuracy: 84.94% | Time elapsed: 134.73s
# Epoch 27 | Training Loss (Avg): 0.053581 | Validation Accuracy: 85.88% | Time elapsed: 134.56s
# Epoch 28 | Training Loss (Avg): 0.050850 | Validation Accuracy: 85.58% | Time elapsed: 134.94s
# Epoch 29 | Training Loss (Avg): 0.054968 | Validation Accuracy: 87.1% | Time elapsed: 134.95s
# Epoch 30 | Training Loss (Avg): 0.043581 | Validation Accuracy: 86.12% | Time elapsed: 134.93s
# Epoch 31 | Training Loss (Avg): 0.040040 | Validation Accuracy: 86.04% | Time elapsed: 134.81s
# Epoch 32 | Training Loss (Avg): 0.034314 | Validation Accuracy: 85.92% | Time elapsed: 134.91s
# Epoch 33 | Training Loss (Avg): 0.039333 | Validation Accuracy: 86.32% | Time elapsed: 134.77s
# Epoch 34 | Training Loss (Avg): 0.039536 | Validation Accuracy: 86.26% | Time elapsed: 134.65s
# Epoch 35 | Training Loss (Avg): 0.030762 | Validation Accuracy: 85.86% | Time elapsed: 135.17s
# Epoch 36 | Training Loss (Avg): 0.034139 | Validation Accuracy: 86.46% | Time elapsed: 135.02s
# Epoch 37 | Training Loss (Avg): 0.031585 | Validation Accuracy: 86.68% | Time elapsed: 135.28s
# Epoch 38 | Training Loss (Avg): 0.027479 | Validation Accuracy: 86.82% | Time elapsed: 134.90s
# Epoch 39 | Training Loss (Avg): 0.022806 | Validation Accuracy: 86.04% | Time elapsed: 134.91s
# Epoch 40 | Training Loss (Avg): 0.024422 | Validation Accuracy: 86.12% | Time elapsed: 135.00s
# Epoch 41 | Training Loss (Avg): 0.037783 | Validation Accuracy: 87.22% | Time elapsed: 134.76s
# Epoch 42 | Training Loss (Avg): 0.026067 | Validation Accuracy: 86.28% | Time elapsed: 134.81s
# Epoch 43 | Training Loss (Avg): 0.028868 | Validation Accuracy: 86.76% | Time elapsed: 134.64s
# Epoch 44 | Training Loss (Avg): 0.018345 | Validation Accuracy: 86.18% | Time elapsed: 134.67s
# Epoch 45 | Training Loss (Avg): 0.018319 | Validation Accuracy: 86.32% | Time elapsed: 134.75s
# Epoch 46 | Training Loss (Avg): 0.023704 | Validation Accuracy: 86.74% | Time elapsed: 134.60s
# Epoch 47 | Training Loss (Avg): 0.024556 | Validation Accuracy: 86.48% | Time elapsed: 134.57s
# Epoch 48 | Training Loss (Avg): 0.023166 | Validation Accuracy: 86.24% | Time elapsed: 134.82s
# Epoch 49 | Training Loss (Avg): 0.020690 | Validation Accuracy: 86.2% | Time elapsed: 134.75s
# Epoch 50 | Training Loss (Avg): 0.017510 | Validation Accuracy: 86.98% | Time elapsed: 134.77s
# Epoch 51 | Training Loss (Avg): 0.018098 | Validation Accuracy: 86.88% | Time elapsed: 134.42s
# Epoch 52 | Training Loss (Avg): 0.011090 | Validation Accuracy: 85.42% | Time elapsed: 134.80s
# Epoch 53 | Training Loss (Avg): 0.015189 | Validation Accuracy: 86.2% | Time elapsed: 134.67s
# Epoch 54 | Training Loss (Avg): 0.014747 | Validation Accuracy: 86.9% | Time elapsed: 134.56s
# Epoch 55 | Training Loss (Avg): 0.010213 | Validation Accuracy: 87.08% | Time elapsed: 134.70s
# Epoch 56 | Training Loss (Avg): 0.010010 | Validation Accuracy: 86.78% | Time elapsed: 134.71s
# Epoch 57 | Training Loss (Avg): 0.011959 | Validation Accuracy: 86.48% | Time elapsed: 134.75s
# Epoch 58 | Training Loss (Avg): 0.013105 | Validation Accuracy: 86.48% | Time elapsed: 134.54s
# Epoch 59 | Training Loss (Avg): 0.026847 | Validation Accuracy: 86.12% | Time elapsed: 134.78s
# Epoch 60 | Training Loss (Avg): 0.015874 | Validation Accuracy: 87.26% | Time elapsed: 135.08s
# Epoch 61 | Training Loss (Avg): 0.008638 | Validation Accuracy: 86.68% | Time elapsed: 134.74s
# Epoch 62 | Training Loss (Avg): 0.008670 | Validation Accuracy: 87.34% | Time elapsed: 134.64s
# Epoch 63 | Training Loss (Avg): 0.010612 | Validation Accuracy: 85.78% | Time elapsed: 134.73s
# Epoch 64 | Training Loss (Avg): 0.011939 | Validation Accuracy: 86.64% | Time elapsed: 134.97s
# Epoch 65 | Training Loss (Avg): 0.014867 | Validation Accuracy: 86.5% | Time elapsed: 135.06s
# Epoch 66 | Training Loss (Avg): 0.013847 | Validation Accuracy: 86.68% | Time elapsed: 134.79s
# Epoch 67 | Training Loss (Avg): 0.009179 | Validation Accuracy: 87.5% | Time elapsed: 134.99s
# Epoch 68 | Training Loss (Avg): 0.005048 | Validation Accuracy: 86.9% | Time elapsed: 134.68s
# Epoch 69 | Training Loss (Avg): 0.008079 | Validation Accuracy: 87.12% | Time elapsed: 134.82s
# Epoch 70 | Training Loss (Avg): 0.010677 | Validation Accuracy: 86.58% | Time elapsed: 134.98s
# Training Complete.

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 87.0%

# %% [markdown]
# # k = 36, depth = 100

# %%
growth_rate = 36
depth = 100
reduction = 0.5
num_classes = 10
bottle_neck_flag = True
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "sparse"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(180, 90, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(90, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(126, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(126, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(162, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(162, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(198, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(198, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(234, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(234, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(180, 90, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(90, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(126, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(126, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(162, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(162, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(198, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(198, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(234, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(234, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=180, out_features=10, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 3.2199M

# %%
batch_size = 32
epochs = 70
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'sparsenet_cifar10_k36_depth100')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 1.583771 | Validation Accuracy: 54.54% | Time elapsed: 302.14s
# Epoch 2 | Training Loss (Avg): 1.062657 | Validation Accuracy: 68.98% | Time elapsed: 307.43s
# Epoch 3 | Training Loss (Avg): 0.784089 | Validation Accuracy: 77.04% | Time elapsed: 307.62s
# Epoch 4 | Training Loss (Avg): 0.613397 | Validation Accuracy: 76.7% | Time elapsed: 308.09s
# Epoch 5 | Training Loss (Avg): 0.505194 | Validation Accuracy: 82.82% | Time elapsed: 307.95s
# Epoch 6 | Training Loss (Avg): 0.429017 | Validation Accuracy: 82.36% | Time elapsed: 308.10s
# Epoch 7 | Training Loss (Avg): 0.365030 | Validation Accuracy: 83.28% | Time elapsed: 308.19s
# Epoch 8 | Training Loss (Avg): 0.311701 | Validation Accuracy: 84.3% | Time elapsed: 308.05s
# Epoch 9 | Training Loss (Avg): 0.267434 | Validation Accuracy: 84.8% | Time elapsed: 308.02s
# Epoch 10 | Training Loss (Avg): 0.231147 | Validation Accuracy: 85.78% | Time elapsed: 306.89s
# Epoch 11 | Training Loss (Avg): 0.197503 | Validation Accuracy: 83.2% | Time elapsed: 307.97s
# Epoch 12 | Training Loss (Avg): 0.174287 | Validation Accuracy: 85.24% | Time elapsed: 307.17s
# Epoch 13 | Training Loss (Avg): 0.152237 | Validation Accuracy: 86.38% | Time elapsed: 307.15s
# Epoch 14 | Training Loss (Avg): 0.126370 | Validation Accuracy: 86.02% | Time elapsed: 307.00s
# Epoch 15 | Training Loss (Avg): 0.122148 | Validation Accuracy: 85.32% | Time elapsed: 308.22s
# Epoch 16 | Training Loss (Avg): 0.104940 | Validation Accuracy: 85.78% | Time elapsed: 307.89s
# Epoch 17 | Training Loss (Avg): 0.094278 | Validation Accuracy: 86.6% | Time elapsed: 306.70s
# Epoch 18 | Training Loss (Avg): 0.076329 | Validation Accuracy: 86.16% | Time elapsed: 308.08s
# Epoch 19 | Training Loss (Avg): 0.081087 | Validation Accuracy: 85.9% | Time elapsed: 308.02s
# Epoch 20 | Training Loss (Avg): 0.066042 | Validation Accuracy: 86.84% | Time elapsed: 308.23s
# Epoch 21 | Training Loss (Avg): 0.064379 | Validation Accuracy: 86.4% | Time elapsed: 307.89s
# Epoch 22 | Training Loss (Avg): 0.050564 | Validation Accuracy: 87.38% | Time elapsed: 306.89s
# Epoch 23 | Training Loss (Avg): 0.047594 | Validation Accuracy: 87.06% | Time elapsed: 306.94s
# Epoch 24 | Training Loss (Avg): 0.053046 | Validation Accuracy: 87.26% | Time elapsed: 307.94s
# Epoch 25 | Training Loss (Avg): 0.043671 | Validation Accuracy: 87.12% | Time elapsed: 307.76s
# Epoch 26 | Training Loss (Avg): 0.035746 | Validation Accuracy: 88.6% | Time elapsed: 308.06s
# Epoch 27 | Training Loss (Avg): 0.043083 | Validation Accuracy: 87.26% | Time elapsed: 307.58s

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 86.0%

# %% [markdown]
# # k = 64, depth = 100

# %%
growth_rate = 64
depth = 100
reduction = 0.5
num_classes = 10
bottle_neck_flag = True
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "sparse"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(320, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(320, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=320, out_features=10, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 10.1343M

# %%
batch_size = 32
epochs = 27
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'sparsenet_cifar10_k64_depth100')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 1.585720 | Validation Accuracy: 57.88% | Time elapsed: 411.98s
# Epoch 2 | Training Loss (Avg): 0.992235 | Validation Accuracy: 68.76% | Time elapsed: 413.73s
# Epoch 3 | Training Loss (Avg): 0.697471 | Validation Accuracy: 77.04% | Time elapsed: 413.81s
# Epoch 4 | Training Loss (Avg): 0.538413 | Validation Accuracy: 83.5% | Time elapsed: 413.58s
# Epoch 5 | Training Loss (Avg): 0.423749 | Validation Accuracy: 84.0% | Time elapsed: 412.89s
# Epoch 6 | Training Loss (Avg): 0.344029 | Validation Accuracy: 84.86% | Time elapsed: 414.37s
# Epoch 7 | Training Loss (Avg): 0.286461 | Validation Accuracy: 84.66% | Time elapsed: 413.56s
# Epoch 8 | Training Loss (Avg): 0.231312 | Validation Accuracy: 85.36% | Time elapsed: 413.72s
# Epoch 9 | Training Loss (Avg): 0.191685 | Validation Accuracy: 86.64% | Time elapsed: 413.72s
# Epoch 10 | Training Loss (Avg): 0.155441 | Validation Accuracy: 85.82% | Time elapsed: 414.41s
# Epoch 11 | Training Loss (Avg): 0.136688 | Validation Accuracy: 85.98% | Time elapsed: 413.62s
# Epoch 12 | Training Loss (Avg): 0.110471 | Validation Accuracy: 86.46% | Time elapsed: 413.46s
# Epoch 13 | Training Loss (Avg): 0.096012 | Validation Accuracy: 87.06% | Time elapsed: 413.87s
# Epoch 14 | Training Loss (Avg): 0.079991 | Validation Accuracy: 87.5% | Time elapsed: 413.44s
# Epoch 15 | Training Loss (Avg): 0.072211 | Validation Accuracy: 87.46% | Time elapsed: 413.97s
# Epoch 16 | Training Loss (Avg): 0.063571 | Validation Accuracy: 88.32% | Time elapsed: 413.81s
# Epoch 17 | Training Loss (Avg): 0.054407 | Validation Accuracy: 87.92% | Time elapsed: 413.96s
# Epoch 18 | Training Loss (Avg): 0.050984 | Validation Accuracy: 87.2% | Time elapsed: 413.63s
# Epoch 19 | Training Loss (Avg): 0.046490 | Validation Accuracy: 88.2% | Time elapsed: 414.00s
# Epoch 20 | Training Loss (Avg): 0.040684 | Validation Accuracy: 88.62% | Time elapsed: 414.42s

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 87.0%

# %% [markdown]
# # k = [16, 32, 64], depth = 100

# %%
growth_rate = 24
depth = 100
reduction = 0.5
num_classes = 10
bottle_neck_flag = True
layers_per_stage = None
growth_rate_per_stage = [16, 32, 64]
drop_prob = 0.0
fetch_type = "sparse"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(24, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(40, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(56, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(88, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(80, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(40, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(104, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(136, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(168, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(160, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(80, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(208, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(272, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(336, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=320, out_features=10, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 4.3337M

# %%
batch_size = 32
epochs = 27
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'sparsenet_cifar10_k163224_depth100')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 1.622380 | Validation Accuracy: 57.54% | Time elapsed: 137.88s
# Epoch 2 | Training Loss (Avg): 1.039837 | Validation Accuracy: 69.8% | Time elapsed: 137.76s
# Epoch 3 | Training Loss (Avg): 0.783207 | Validation Accuracy: 75.34% | Time elapsed: 137.80s
# Epoch 4 | Training Loss (Avg): 0.622063 | Validation Accuracy: 77.54% | Time elapsed: 137.75s
# Epoch 5 | Training Loss (Avg): 0.519649 | Validation Accuracy: 81.28% | Time elapsed: 137.73s
# Epoch 6 | Training Loss (Avg): 0.437925 | Validation Accuracy: 81.96% | Time elapsed: 138.05s
# Epoch 7 | Training Loss (Avg): 0.377451 | Validation Accuracy: 83.34% | Time elapsed: 137.76s
# Epoch 8 | Training Loss (Avg): 0.319018 | Validation Accuracy: 83.24% | Time elapsed: 137.78s
# Epoch 9 | Training Loss (Avg): 0.274065 | Validation Accuracy: 84.68% | Time elapsed: 137.99s
# Epoch 10 | Training Loss (Avg): 0.231926 | Validation Accuracy: 84.36% | Time elapsed: 138.00s
# Epoch 11 | Training Loss (Avg): 0.198381 | Validation Accuracy: 84.16% | Time elapsed: 137.82s
# Epoch 12 | Training Loss (Avg): 0.172982 | Validation Accuracy: 84.76% | Time elapsed: 137.74s
# Epoch 13 | Training Loss (Avg): 0.146045 | Validation Accuracy: 85.18% | Time elapsed: 137.92s
# Epoch 14 | Training Loss (Avg): 0.132581 | Validation Accuracy: 85.74% | Time elapsed: 137.75s
# Epoch 15 | Training Loss (Avg): 0.112543 | Validation Accuracy: 84.66% | Time elapsed: 137.68s
# Epoch 16 | Training Loss (Avg): 0.097770 | Validation Accuracy: 85.84% | Time elapsed: 137.77s
# Epoch 17 | Training Loss (Avg): 0.083364 | Validation Accuracy: 86.92% | Time elapsed: 137.71s
# Epoch 18 | Training Loss (Avg): 0.075841 | Validation Accuracy: 86.02% | Time elapsed: 137.74s
# Epoch 19 | Training Loss (Avg): 0.067516 | Validation Accuracy: 86.7% | Time elapsed: 138.08s
# Epoch 20 | Training Loss (Avg): 0.057869 | Validation Accuracy: 85.12% | Time elapsed: 137.76s
# Epoch 21 | Training Loss (Avg): 0.055868 | Validation Accuracy: 85.88% | Time elapsed: 137.81s
# Epoch 22 | Training Loss (Avg): 0.049877 | Validation Accuracy: 86.0% | Time elapsed: 138.00s
# Epoch 23 | Training Loss (Avg): 0.058443 | Validation Accuracy: 86.3% | Time elapsed: 137.78s
# Epoch 24 | Training Loss (Avg): 0.041950 | Validation Accuracy: 85.52% | Time elapsed: 138.04s
# Epoch 25 | Training Loss (Avg): 0.039603 | Validation Accuracy: 86.16% | Time elapsed: 137.72s
# Epoch 26 | Training Loss (Avg): 0.038623 | Validation Accuracy: 86.76% | Time elapsed: 137.82s
# Epoch 27 | Training Loss (Avg): 0.033582 | Validation Accuracy: 87.64% | Time elapsed: 137.73s
# Training Complete.

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 87.0%

# %% [markdown]
# # k = 24, depth = 100, without using bottleneck compression

# %%
growth_rate = 24
depth = 100
reduction = 0.5
num_classes = 10
bottle_neck_flag = False
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "sparse"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(168, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(216, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(240, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(264, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(168, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(216, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(240, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(264, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=144, out_features=10, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 2.4773M

# %%
batch_size = 32
epochs = 27
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'sparsenet_cifar10_k24_depth100_nobc')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 1.474023 | Validation Accuracy: 57.3% | Time elapsed: 239.03s
# Epoch 2 | Training Loss (Avg): 0.854941 | Validation Accuracy: 74.7% | Time elapsed: 241.88s
# Epoch 3 | Training Loss (Avg): 0.630884 | Validation Accuracy: 79.64% | Time elapsed: 241.93s
# Epoch 4 | Training Loss (Avg): 0.510883 | Validation Accuracy: 81.88% | Time elapsed: 241.81s
# Epoch 5 | Training Loss (Avg): 0.423833 | Validation Accuracy: 79.98% | Time elapsed: 242.44s
# Epoch 6 | Training Loss (Avg): 0.354983 | Validation Accuracy: 83.94% | Time elapsed: 241.70s
# Epoch 7 | Training Loss (Avg): 0.300270 | Validation Accuracy: 85.18% | Time elapsed: 241.91s
# Epoch 8 | Training Loss (Avg): 0.255616 | Validation Accuracy: 85.26% | Time elapsed: 241.70s
# Epoch 9 | Training Loss (Avg): 0.219493 | Validation Accuracy: 85.84% | Time elapsed: 241.82s
# Epoch 10 | Training Loss (Avg): 0.184466 | Validation Accuracy: 85.8% | Time elapsed: 241.94s
# Epoch 11 | Training Loss (Avg): 0.154972 | Validation Accuracy: 85.8% | Time elapsed: 241.78s
# Epoch 12 | Training Loss (Avg): 0.139598 | Validation Accuracy: 85.64% | Time elapsed: 241.74s
# Epoch 13 | Training Loss (Avg): 0.111964 | Validation Accuracy: 86.18% | Time elapsed: 241.76s
# Epoch 14 | Training Loss (Avg): 0.105920 | Validation Accuracy: 86.14% | Time elapsed: 241.68s
# Epoch 15 | Training Loss (Avg): 0.090124 | Validation Accuracy: 86.08% | Time elapsed: 241.66s
# Epoch 16 | Training Loss (Avg): 0.075899 | Validation Accuracy: 85.84% | Time elapsed: 241.93s
# Epoch 17 | Training Loss (Avg): 0.070435 | Validation Accuracy: 85.74% | Time elapsed: 241.80s
# Epoch 18 | Training Loss (Avg): 0.059887 | Validation Accuracy: 87.6% | Time elapsed: 241.56s
# Epoch 19 | Training Loss (Avg): 0.061554 | Validation Accuracy: 86.9% | Time elapsed: 241.95s
# Epoch 20 | Training Loss (Avg): 0.049212 | Validation Accuracy: 86.2% | Time elapsed: 241.89s
# Epoch 21 | Training Loss (Avg): 0.053316 | Validation Accuracy: 86.98% | Time elapsed: 241.95s
# Epoch 22 | Training Loss (Avg): 0.031749 | Validation Accuracy: 86.44% | Time elapsed: 241.80s

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 87.0%

# %% [markdown]
# # k = 36, depth = 100, without using bottleneck compression

# %%
growth_rate = 36
depth = 100
reduction = 0.5
num_classes = 10
bottle_neck_flag = False
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "sparse"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(36, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(216, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(216, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(252, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(252, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(324, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(360, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(396, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(396, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(216, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(252, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(252, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(324, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(360, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(396, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(396, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=216, out_features=10, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 5.5550M

# %%
batch_size = 32
epochs = 27
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'sparsenet_cifar10_k36_depth100_nobc')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 1.482211 | Validation Accuracy: 63.5% | Time elapsed: 463.38s
# Epoch 2 | Training Loss (Avg): 0.846644 | Validation Accuracy: 76.14% | Time elapsed: 471.92s
# Epoch 3 | Training Loss (Avg): 0.618749 | Validation Accuracy: 80.78% | Time elapsed: 471.02s
# Epoch 4 | Training Loss (Avg): 0.483096 | Validation Accuracy: 84.66% | Time elapsed: 471.35s
# Epoch 5 | Training Loss (Avg): 0.395122 | Validation Accuracy: 85.68% | Time elapsed: 470.82s
# Epoch 6 | Training Loss (Avg): 0.330204 | Validation Accuracy: 86.48% | Time elapsed: 470.84s
# Epoch 7 | Training Loss (Avg): 0.272281 | Validation Accuracy: 88.04% | Time elapsed: 471.55s
# Epoch 8 | Training Loss (Avg): 0.227267 | Validation Accuracy: 87.18% | Time elapsed: 471.61s
# Epoch 9 | Training Loss (Avg): 0.192610 | Validation Accuracy: 87.98% | Time elapsed: 471.30s
# Epoch 10 | Training Loss (Avg): 0.157642 | Validation Accuracy: 87.82% | Time elapsed: 470.99s
# Epoch 11 | Training Loss (Avg): 0.136675 | Validation Accuracy: 87.46% | Time elapsed: 471.27s
# Epoch 12 | Training Loss (Avg): 0.109668 | Validation Accuracy: 87.1% | Time elapsed: 471.61s

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 86.0%
