# %%
import os
import math
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
import time

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split

from torchvision.datasets import CIFAR100

from model_architecture import *

# %% [markdown]
# # Dataset preparation

# %%
def get_dataset(train_val_split = 0.9):

    transform  = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ])
    
    train_data = CIFAR100(root='./data', train = True, download = first_run, transform = transform)
    test_data  = CIFAR100(root='./data', train = False, download = first_run, transform = transform)

    train_size = int(train_val_split * len(train_data))
    val_size = len(train_data) - train_size


    train_data, val_data = random_split(train_data, [train_size, val_size])
    
    return train_data, val_data, test_data


def get_dataloader(batch_size, train_val_split = 0.9, num_workers = 1):
    
    train_set, val_set, test_set = get_dataset(train_val_split)
    trainloader = DataLoader(train_set, batch_size = batch_size, shuffle = True, num_workers = num_workers, pin_memory = True)
    valloader = DataLoader(val_set, batch_size = batch_size, shuffle = False, num_workers = num_workers, pin_memory = True)
    testloader = DataLoader(test_set, batch_size = batch_size, shuffle = False, num_workers = num_workers, pin_memory = True)

    return trainloader, valloader, testloader

# %% [markdown]
# # k = 12, depth = 40

# %%
growth_rate = 12
depth = 40 
reduction = 0.5
num_classes = 100
bottle_neck_flag = True
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "dense"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(36, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(60, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(84, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(60, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(84, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(120, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(60, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(84, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=132, out_features=100, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 0.1881M

# %%
batch_size = 32
epochs = 30
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'dense_cifar100_k12_depth40')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 3.919220 | Validation Accuracy: 14.34% | Time elapsed: 26.84s
# Epoch 2 | Training Loss (Avg): 3.341984 | Validation Accuracy: 24.98% | Time elapsed: 25.95s
# Epoch 3 | Training Loss (Avg): 2.849911 | Validation Accuracy: 32.86% | Time elapsed: 27.16s
# Epoch 4 | Training Loss (Avg): 2.487821 | Validation Accuracy: 34.92% | Time elapsed: 25.76s
# Epoch 5 | Training Loss (Avg): 2.265102 | Validation Accuracy: 39.68% | Time elapsed: 26.20s
# Epoch 6 | Training Loss (Avg): 2.123538 | Validation Accuracy: 42.2% | Time elapsed: 25.58s
# Epoch 7 | Training Loss (Avg): 2.008504 | Validation Accuracy: 45.08% | Time elapsed: 26.60s
# Epoch 8 | Training Loss (Avg): 1.910219 | Validation Accuracy: 47.04% | Time elapsed: 26.53s
# Epoch 9 | Training Loss (Avg): 1.831103 | Validation Accuracy: 46.88% | Time elapsed: 24.95s
# Epoch 10 | Training Loss (Avg): 1.765955 | Validation Accuracy: 47.5% | Time elapsed: 26.31s
# Epoch 11 | Training Loss (Avg): 1.711262 | Validation Accuracy: 48.9% | Time elapsed: 26.39s
# Epoch 12 | Training Loss (Avg): 1.650762 | Validation Accuracy: 49.3% | Time elapsed: 27.01s
# Epoch 13 | Training Loss (Avg): 1.597285 | Validation Accuracy: 51.36% | Time elapsed: 26.42s
# Epoch 14 | Training Loss (Avg): 1.558706 | Validation Accuracy: 49.72% | Time elapsed: 26.90s
# Epoch 15 | Training Loss (Avg): 1.515659 | Validation Accuracy: 51.06% | Time elapsed: 26.23s
# Epoch 16 | Training Loss (Avg): 1.476056 | Validation Accuracy: 51.78% | Time elapsed: 26.97s
# Epoch 17 | Training Loss (Avg): 1.444350 | Validation Accuracy: 51.12% | Time elapsed: 26.39s
# Epoch 18 | Training Loss (Avg): 1.412393 | Validation Accuracy: 52.08% | Time elapsed: 26.88s
# Epoch 19 | Training Loss (Avg): 1.371651 | Validation Accuracy: 50.48% | Time elapsed: 27.21s
# Epoch 20 | Training Loss (Avg): 1.346448 | Validation Accuracy: 53.06% | Time elapsed: 25.36s
# Epoch 21 | Training Loss (Avg): 1.320199 | Validation Accuracy: 53.12% | Time elapsed: 26.50s
# Epoch 22 | Training Loss (Avg): 1.294059 | Validation Accuracy: 52.78% | Time elapsed: 26.74s
# Epoch 23 | Training Loss (Avg): 1.259421 | Validation Accuracy: 52.86% | Time elapsed: 25.55s
# Epoch 24 | Training Loss (Avg): 1.236238 | Validation Accuracy: 51.4% | Time elapsed: 25.86s
# Epoch 25 | Training Loss (Avg): 1.221054 | Validation Accuracy: 52.24% | Time elapsed: 25.27s
# Epoch 26 | Training Loss (Avg): 1.187351 | Validation Accuracy: 52.6% | Time elapsed: 27.03s
# Epoch 27 | Training Loss (Avg): 1.171593 | Validation Accuracy: 53.28% | Time elapsed: 25.60s
# Epoch 28 | Training Loss (Avg): 1.141507 | Validation Accuracy: 53.38% | Time elapsed: 27.00s
# Epoch 29 | Training Loss (Avg): 1.126355 | Validation Accuracy: 52.82% | Time elapsed: 25.07s
# Epoch 30 | Training Loss (Avg): 1.102824 | Validation Accuracy: 53.72% | Time elapsed: 25.29s

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 54.0%

# %% [markdown]
# # k = 24, depth = 100

# %%
growth_rate = 24
depth = 100
reduction = 0.5
num_classes = 100
bottle_neck_flag = True
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "dense"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(168, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(216, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(240, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(264, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(312, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(336, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(360, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(408, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(432, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(216, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(240, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(264, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(312, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(336, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(360, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(408, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(432, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(456, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(456, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(504, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(528, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(552, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(552, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(600, 300, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(300, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(324, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(348, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(348, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(372, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(372, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(396, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(396, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(420, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(420, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(444, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(444, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(468, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(468, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(492, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(492, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(516, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(516, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(540, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(540, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(564, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(564, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(588, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(588, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(612, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(612, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(636, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(636, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(660, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(660, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(684, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=684, out_features=100, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 3.0822M

# %%
batch_size = 32
epochs = 27
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'densenet_cifar100_k24_depth100')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 3.896795 | Validation Accuracy: 16.98% | Time elapsed: 256.02s
# Epoch 2 | Training Loss (Avg): 3.021787 | Validation Accuracy: 30.94% | Time elapsed: 256.33s
# Epoch 3 | Training Loss (Avg): 2.339274 | Validation Accuracy: 41.18% | Time elapsed: 256.32s
# Epoch 4 | Training Loss (Avg): 1.903393 | Validation Accuracy: 48.52% | Time elapsed: 256.79s
# Epoch 5 | Training Loss (Avg): 1.599359 | Validation Accuracy: 51.82% | Time elapsed: 257.21s
# Epoch 6 | Training Loss (Avg): 1.376624 | Validation Accuracy: 54.2% | Time elapsed: 256.62s
# Epoch 7 | Training Loss (Avg): 1.197619 | Validation Accuracy: 57.52% | Time elapsed: 256.37s
# Epoch 8 | Training Loss (Avg): 1.034492 | Validation Accuracy: 57.7% | Time elapsed: 256.73s
# Epoch 9 | Training Loss (Avg): 0.897448 | Validation Accuracy: 58.4% | Time elapsed: 256.77s
# Epoch 10 | Training Loss (Avg): 0.776310 | Validation Accuracy: 59.84% | Time elapsed: 256.67s
# Epoch 11 | Training Loss (Avg): 0.667126 | Validation Accuracy: 59.5% | Time elapsed: 256.90s
# Epoch 12 | Training Loss (Avg): 0.563905 | Validation Accuracy: 62.06% | Time elapsed: 256.74s
# Epoch 13 | Training Loss (Avg): 0.474892 | Validation Accuracy: 60.84% | Time elapsed: 256.35s
# Epoch 14 | Training Loss (Avg): 0.414968 | Validation Accuracy: 60.74% | Time elapsed: 256.40s
# Epoch 15 | Training Loss (Avg): 0.359691 | Validation Accuracy: 61.02% | Time elapsed: 256.81s
# Epoch 16 | Training Loss (Avg): 0.298670 | Validation Accuracy: 61.32% | Time elapsed: 256.92s
# Epoch 17 | Training Loss (Avg): 0.249800 | Validation Accuracy: 61.14% | Time elapsed: 256.53s
# Epoch 18 | Training Loss (Avg): 0.231836 | Validation Accuracy: 61.92% | Time elapsed: 256.76s
# Epoch 19 | Training Loss (Avg): 0.196980 | Validation Accuracy: 60.46% | Time elapsed: 256.30s
# Epoch 20 | Training Loss (Avg): 0.178973 | Validation Accuracy: 62.6% | Time elapsed: 256.37s
# Epoch 21 | Training Loss (Avg): 0.141772 | Validation Accuracy: 63.64% | Time elapsed: 256.98s
# Epoch 22 | Training Loss (Avg): 0.126989 | Validation Accuracy: 62.88% | Time elapsed: 256.82s
# Epoch 23 | Training Loss (Avg): 0.128990 | Validation Accuracy: 62.38% | Time elapsed: 256.53s
# Epoch 24 | Training Loss (Avg): 0.110001 | Validation Accuracy: 63.0% | Time elapsed: 256.85s
# Epoch 25 | Training Loss (Avg): 0.099859 | Validation Accuracy: 63.54% | Time elapsed: 256.59s
# Epoch 26 | Training Loss (Avg): 0.089962 | Validation Accuracy: 63.4% | Time elapsed: 256.65s
# Epoch 27 | Training Loss (Avg): 0.086336 | Validation Accuracy: 63.72% | Time elapsed: 256.58s
# Training Complete.

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 65.0%

# %% [markdown]
# # k = 36, depth = 100

# %%
growth_rate = 36
depth = 100
reduction = 0.5
num_classes = 100
bottle_neck_flag = True
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "dense"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(216, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(252, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(252, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(324, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(360, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(396, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(396, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(468, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(468, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(504, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(540, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(540, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(612, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(612, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(648, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(648, 324, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(324, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(360, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(396, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(396, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(468, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(468, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(504, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(540, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(540, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(612, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(612, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(648, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(648, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(684, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(684, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(720, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(756, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(756, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(792, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(828, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(828, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(900, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(900, 450, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(450, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(450, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(486, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(486, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(522, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(522, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(558, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(558, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(594, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(594, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(630, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(630, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(666, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(666, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(702, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(702, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(738, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(738, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(774, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(774, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(810, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(810, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(846, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(846, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(882, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(882, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(918, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(918, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(954, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(954, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(990, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(990, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(1026, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=1026, out_features=100, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 6.8465M

# %%
batch_size = 32
epochs = 20
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'densenet_cifar100_k36_depth100')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 3.969072 | Validation Accuracy: 15.7% | Time elapsed: 523.87s
# Epoch 2 | Training Loss (Avg): 3.106440 | Validation Accuracy: 30.66% | Time elapsed: 528.92s
# Epoch 3 | Training Loss (Avg): 2.385965 | Validation Accuracy: 42.78% | Time elapsed: 528.70s
# Epoch 4 | Training Loss (Avg): 1.901433 | Validation Accuracy: 48.38% | Time elapsed: 529.02s
# Epoch 5 | Training Loss (Avg): 1.590301 | Validation Accuracy: 54.3% | Time elapsed: 528.54s
# Epoch 6 | Training Loss (Avg): 1.346518 | Validation Accuracy: 55.32% | Time elapsed: 528.87s
# Epoch 7 | Training Loss (Avg): 1.153374 | Validation Accuracy: 57.4% | Time elapsed: 529.69s
# Epoch 8 | Training Loss (Avg): 0.985065 | Validation Accuracy: 60.38% | Time elapsed: 530.04s
# Epoch 9 | Training Loss (Avg): 0.825549 | Validation Accuracy: 58.44% | Time elapsed: 529.42s
# Epoch 10 | Training Loss (Avg): 0.690949 | Validation Accuracy: 60.58% | Time elapsed: 529.63s
# Epoch 11 | Training Loss (Avg): 0.576682 | Validation Accuracy: 59.54% | Time elapsed: 530.08s
# Epoch 12 | Training Loss (Avg): 0.475596 | Validation Accuracy: 60.56% | Time elapsed: 528.17s
# Epoch 13 | Training Loss (Avg): 0.383884 | Validation Accuracy: 60.66% | Time elapsed: 529.52s
# Epoch 14 | Training Loss (Avg): 0.320580 | Validation Accuracy: 61.3% | Time elapsed: 529.87s
# Epoch 15 | Training Loss (Avg): 0.276765 | Validation Accuracy: 61.38% | Time elapsed: 529.23s
# Epoch 16 | Training Loss (Avg): 0.218444 | Validation Accuracy: 61.76% | Time elapsed: 529.83s
# Epoch 17 | Training Loss (Avg): 0.198196 | Validation Accuracy: 62.02% | Time elapsed: 528.66s
# Epoch 18 | Training Loss (Avg): 0.162832 | Validation Accuracy: 61.9% | Time elapsed: 528.55s
# Epoch 19 | Training Loss (Avg): 0.134094 | Validation Accuracy: 61.64% | Time elapsed: 528.48s
# Epoch 20 | Training Loss (Avg): 0.116285 | Validation Accuracy: 63.22% | Time elapsed: 528.90s
# Training Complete.

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 64.0%

# %% [markdown]
# # k = 64, depth = 100

# %%
growth_rate = 64
depth = 100
reduction = 0.5
num_classes = 100
bottle_neck_flag = True
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "dense"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1088, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(1152, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1088, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(1216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1216, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1408, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(1472, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1472, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(1600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(1600, 800, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(1120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1120, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(1184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1184, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(1312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1312, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(1376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1376, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(1504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1504, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(1568, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1568, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(1696, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1696, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(1760, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1760, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=1824, out_features=100, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 21.3940M

# %%
batch_size = 32
epochs = 20
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'densenet_cifar100_k64_depth100')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 3.991123 | Validation Accuracy: 14.56% | Time elapsed: 888.88s
# Epoch 2 | Training Loss (Avg): 3.149380 | Validation Accuracy: 25.36% | Time elapsed: 890.74s
# Epoch 3 | Training Loss (Avg): 2.491373 | Validation Accuracy: 39.56% | Time elapsed: 892.15s
# Epoch 4 | Training Loss (Avg): 1.960120 | Validation Accuracy: 48.98% | Time elapsed: 892.43s
# Epoch 5 | Training Loss (Avg): 1.618977 | Validation Accuracy: 53.62% | Time elapsed: 892.49s
# Epoch 6 | Training Loss (Avg): 1.357318 | Validation Accuracy: 55.12% | Time elapsed: 893.28s
# Epoch 7 | Training Loss (Avg): 1.141584 | Validation Accuracy: 58.74% | Time elapsed: 893.85s
# Epoch 8 | Training Loss (Avg): 0.943368 | Validation Accuracy: 58.48% | Time elapsed: 894.44s
# Epoch 9 | Training Loss (Avg): 0.778901 | Validation Accuracy: 61.22% | Time elapsed: 894.56s
# Epoch 10 | Training Loss (Avg): 0.632362 | Validation Accuracy: 60.52% | Time elapsed: 893.84s
# Epoch 11 | Training Loss (Avg): 0.480844 | Validation Accuracy: 60.04% | Time elapsed: 893.95s
# Epoch 12 | Training Loss (Avg): 0.392521 | Validation Accuracy: 58.46% | Time elapsed: 895.15s
# Epoch 13 | Training Loss (Avg): 0.317530 | Validation Accuracy: 60.72% | Time elapsed: 894.48s
# Epoch 14 | Training Loss (Avg): 0.239737 | Validation Accuracy: 61.82% | Time elapsed: 894.01s
# Epoch 15 | Training Loss (Avg): 0.196684 | Validation Accuracy: 60.94% | Time elapsed: 893.86s
# Epoch 16 | Training Loss (Avg): 0.163096 | Validation Accuracy: 62.42% | Time elapsed: 894.32s
# Epoch 17 | Training Loss (Avg): 0.118193 | Validation Accuracy: 61.94% | Time elapsed: 894.17s
# Epoch 18 | Training Loss (Avg): 0.120839 | Validation Accuracy: 63.06% | Time elapsed: 894.17s
# Epoch 19 | Training Loss (Avg): 0.086953 | Validation Accuracy: 62.5% | Time elapsed: 893.66s
# Epoch 20 | Training Loss (Avg): 0.080216 | Validation Accuracy: 64.32% | Time elapsed: 893.57s

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 63.0%

# %% [markdown]
# # k = [16, 32, 64], depth = 100

# %%
growth_rate = 24
depth = 100
reduction = 0.5
num_classes = 100
bottle_neck_flag = True
layers_per_stage = None
growth_rate_per_stage = [16, 32, 64]
drop_prob = 0.0
fetch_type = "dense"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(80, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(112, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(176, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(208, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(272, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(304, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(152, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(184, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(216, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(248, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(280, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(312, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(344, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(376, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(408, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(440, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(472, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(472, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(504, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(536, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(568, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(568, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(600, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(632, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(664, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(664, 332, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): bottle_neck(
#         (batch_norm1): BatchNorm2d(332, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(332, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): bottle_neck(
#         (batch_norm1): BatchNorm2d(396, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(396, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): bottle_neck(
#         (batch_norm1): BatchNorm2d(460, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(460, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): bottle_neck(
#         (batch_norm1): BatchNorm2d(524, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(524, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): bottle_neck(
#         (batch_norm1): BatchNorm2d(588, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(588, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): bottle_neck(
#         (batch_norm1): BatchNorm2d(652, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(652, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): bottle_neck(
#         (batch_norm1): BatchNorm2d(716, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(716, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): bottle_neck(
#         (batch_norm1): BatchNorm2d(780, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(780, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): bottle_neck(
#         (batch_norm1): BatchNorm2d(844, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(844, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): bottle_neck(
#         (batch_norm1): BatchNorm2d(908, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(908, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): bottle_neck(
#         (batch_norm1): BatchNorm2d(972, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(972, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): bottle_neck(
#         (batch_norm1): BatchNorm2d(1036, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1036, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): bottle_neck(
#         (batch_norm1): BatchNorm2d(1100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1100, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): bottle_neck(
#         (batch_norm1): BatchNorm2d(1164, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1164, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): bottle_neck(
#         (batch_norm1): BatchNorm2d(1228, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1228, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): bottle_neck(
#         (batch_norm1): BatchNorm2d(1292, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1292, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batch_norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(1356, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=1356, out_features=100, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 7.8639M

# %%
batch_size = 32
epochs = 20
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'densenet_cifar100_k163224_depth100')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 3.961706 | Validation Accuracy: 15.0% | Time elapsed: 250.78s
# Epoch 2 | Training Loss (Avg): 3.162431 | Validation Accuracy: 28.3% | Time elapsed: 250.65s
# Epoch 3 | Training Loss (Avg): 2.552028 | Validation Accuracy: 38.98% | Time elapsed: 251.04s
# Epoch 4 | Training Loss (Avg): 2.050449 | Validation Accuracy: 42.72% | Time elapsed: 250.98s
# Epoch 5 | Training Loss (Avg): 1.708086 | Validation Accuracy: 51.04% | Time elapsed: 251.45s
# Epoch 6 | Training Loss (Avg): 1.437086 | Validation Accuracy: 53.62% | Time elapsed: 250.88s
# Epoch 7 | Training Loss (Avg): 1.214127 | Validation Accuracy: 55.14% | Time elapsed: 251.01s
# Epoch 8 | Training Loss (Avg): 1.021155 | Validation Accuracy: 57.08% | Time elapsed: 251.14s
# Epoch 9 | Training Loss (Avg): 0.853671 | Validation Accuracy: 57.38% | Time elapsed: 251.18s
# Epoch 10 | Training Loss (Avg): 0.689906 | Validation Accuracy: 59.04% | Time elapsed: 251.13s
# Epoch 11 | Training Loss (Avg): 0.550240 | Validation Accuracy: 59.9% | Time elapsed: 251.00s
# Epoch 12 | Training Loss (Avg): 0.427130 | Validation Accuracy: 59.94% | Time elapsed: 251.01s
# Epoch 13 | Training Loss (Avg): 0.329533 | Validation Accuracy: 60.12% | Time elapsed: 251.10s
# Epoch 14 | Training Loss (Avg): 0.280650 | Validation Accuracy: 55.92% | Time elapsed: 251.32s
# Epoch 15 | Training Loss (Avg): 0.230081 | Validation Accuracy: 59.32% | Time elapsed: 251.11s
# Epoch 16 | Training Loss (Avg): 0.185584 | Validation Accuracy: 60.1% | Time elapsed: 251.07s
# Epoch 17 | Training Loss (Avg): 0.150382 | Validation Accuracy: 60.6% | Time elapsed: 251.26s
# Epoch 18 | Training Loss (Avg): 0.127396 | Validation Accuracy: 61.22% | Time elapsed: 251.43s
# Epoch 19 | Training Loss (Avg): 0.103617 | Validation Accuracy: 60.9% | Time elapsed: 251.69s
# Epoch 20 | Training Loss (Avg): 0.101169 | Validation Accuracy: 61.7% | Time elapsed: 251.64s
# Training Complete.

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 62.0%

# %% [markdown]
# # k = 24, depth = 100, without using bottleneck compression

# %%
growth_rate = 24
depth = 100
reduction = 0.5
num_classes = 100
bottle_neck_flag = False
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "dense"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(48, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(120, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(168, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(216, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(240, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(264, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(312, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(336, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(360, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(408, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(432, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(456, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(456, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(504, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(528, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(552, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(552, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(600, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(624, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(624, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(648, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(648, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(696, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(696, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(720, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(744, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(744, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(792, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(816, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(816, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(840, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(840, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(888, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(888, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(912, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(912, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(936, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(936, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(984, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(984, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(1008, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1008, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(1032, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1032, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(1080, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1080, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(1104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1104, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(1128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1128, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(1176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1176, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1200, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(1224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1224, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(1272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1272, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(1296, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1296, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(1320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1320, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(1368, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1368, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1392, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(1416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1416, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(1464, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1464, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(1488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1488, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(1512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(1560, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1560, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(1584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(1584, 1584, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(1584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1584, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(1608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1608, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(1656, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1656, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(1680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1680, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(1704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1704, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(1752, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1752, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(1776, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1776, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(1800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1800, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1824, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(1848, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1848, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(1872, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1872, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(1896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1896, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1920, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(1944, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1944, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1968, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(1992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1992, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(2016, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2016, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(2040, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2040, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2064, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(2088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2088, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2112, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(2136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2136, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(2160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2160, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(2184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2184, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(2208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2208, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(2232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2232, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(2256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(2280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2280, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2304, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(2328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2328, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(2352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=2352, out_features=100, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 28.2835M

# %%
batch_size = 16
epochs = 20
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'densenet_cifar100_k24_depth100_nobc')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 4.054365 | Validation Accuracy: 17.02% | Time elapsed: 1689.45s
# Epoch 2 | Training Loss (Avg): 3.214349 | Validation Accuracy: 28.76% | Time elapsed: 1701.92s
# Epoch 3 | Training Loss (Avg): 2.584100 | Validation Accuracy: 38.74% | Time elapsed: 1704.49s
# Epoch 4 | Training Loss (Avg): 2.086738 | Validation Accuracy: 45.08% | Time elapsed: 1706.26s
# Epoch 5 | Training Loss (Avg): 1.748886 | Validation Accuracy: 50.7% | Time elapsed: 1706.81s
# Epoch 6 | Training Loss (Avg): 1.488756 | Validation Accuracy: 54.02% | Time elapsed: 1706.71s
# Epoch 7 | Training Loss (Avg): 1.278005 | Validation Accuracy: 57.6% | Time elapsed: 1706.13s
# Epoch 8 | Training Loss (Avg): 1.099473 | Validation Accuracy: 55.4% | Time elapsed: 1707.23s
# Epoch 9 | Training Loss (Avg): 0.942715 | Validation Accuracy: 58.46% | Time elapsed: 1705.91s
# Epoch 10 | Training Loss (Avg): 0.774427 | Validation Accuracy: 57.3% | Time elapsed: 1705.61s
# Epoch 11 | Training Loss (Avg): 0.626260 | Validation Accuracy: 60.86% | Time elapsed: 1706.07s
# Epoch 12 | Training Loss (Avg): 0.500636 | Validation Accuracy: 57.26% | Time elapsed: 1705.37s
# Epoch 13 | Training Loss (Avg): 0.405281 | Validation Accuracy: 55.92% | Time elapsed: 1705.82s
# Epoch 14 | Training Loss (Avg): 0.302430 | Validation Accuracy: 60.52% | Time elapsed: 1706.36s
# Epoch 15 | Training Loss (Avg): 0.238250 | Validation Accuracy: 61.4% | Time elapsed: 1705.97s
# Epoch 16 | Training Loss (Avg): 0.182335 | Validation Accuracy: 57.2% | Time elapsed: 1707.06s
# Epoch 17 | Training Loss (Avg): 0.153179 | Validation Accuracy: 60.22% | Time elapsed: 1706.12s
# Epoch 18 | Training Loss (Avg): 0.117464 | Validation Accuracy: 61.66% | Time elapsed: 1706.39s
# Epoch 19 | Training Loss (Avg): 0.082337 | Validation Accuracy: 58.54% | Time elapsed: 1706.06s
# Epoch 20 | Training Loss (Avg): 0.071482 | Validation Accuracy: 58.5% | Time elapsed: 1706.54s
# Training Complete.

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 62.0%

# %% [markdown]
# # k = 36, depth = 100, without using bottleneck compression

# %%
growth_rate = 36
depth = 100
reduction = 0.5
num_classes = 100
bottle_neck_flag = False
layers_per_stage = None
growth_rate_per_stage = None
drop_prob = 0.0
fetch_type = "dense"

torch.manual_seed(0)
np.random.seed(0)

net = Model(growth_rate = growth_rate, 
            depth = depth, 
            reduction = reduction,
            num_classes = num_classes,
            bottle_neck_flag = bottle_neck_flag,
            layers_per_stage = layers_per_stage,
            growth_rate_per_stage = growth_rate_per_stage, 
            drop_prob = drop_prob,
            fetch_type = fetch_type)

print(net)
total_params = sum([p.data.nelement() for p in net.parameters()])

print('')
print('Total trainable parameters in the network: %.4f' % (total_params / 1e6) + 'M')
# Out:
# Model(
#   (features): Sequential(
#     (conv0): Conv2d(3, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dense-stage-0): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(72, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(108, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(180, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(216, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(252, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(252, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(324, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(360, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(396, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(396, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(432, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(468, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(468, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(504, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(540, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(540, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(612, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(612, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(648, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(648, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(684, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(684, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(720, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(756, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(756, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(792, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(828, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(828, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(900, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(900, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(936, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(936, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(972, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(972, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(1008, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1008, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1044, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(1080, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1080, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(1116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1116, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(1188, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1188, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-0): transition_layer(
#       (batch_norm1): BatchNorm2d(1224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(1224, 1224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-1): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(1224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1224, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(1260, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1260, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(1296, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1296, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(1332, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1332, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(1368, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1368, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(1404, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1404, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(1476, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1476, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(1512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1512, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(1548, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1548, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(1584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1584, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(1620, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1620, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(1656, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1656, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(1692, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1692, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(1764, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1764, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(1800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1800, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(1836, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1836, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(1872, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1872, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(1908, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1908, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(1944, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1944, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(1980, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1980, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(2016, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2016, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(2052, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2052, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(2088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2088, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(2124, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2124, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(2160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2160, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(2196, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2196, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(2232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2232, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(2268, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2268, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2304, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(2340, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2340, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition-1): transition_layer(
#       (batch_norm1): BatchNorm2d(2376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(2376, 2376, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense-stage-2): dense_stage(
#       (block-1): single_layer(
#         (batch_norm1): BatchNorm2d(2376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2376, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-2): single_layer(
#         (batch_norm1): BatchNorm2d(2412, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2412, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-3): single_layer(
#         (batch_norm1): BatchNorm2d(2448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2448, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-4): single_layer(
#         (batch_norm1): BatchNorm2d(2484, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2484, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-5): single_layer(
#         (batch_norm1): BatchNorm2d(2520, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2520, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-6): single_layer(
#         (batch_norm1): BatchNorm2d(2556, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2556, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-7): single_layer(
#         (batch_norm1): BatchNorm2d(2592, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2592, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-8): single_layer(
#         (batch_norm1): BatchNorm2d(2628, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2628, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-9): single_layer(
#         (batch_norm1): BatchNorm2d(2664, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2664, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-10): single_layer(
#         (batch_norm1): BatchNorm2d(2700, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2700, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-11): single_layer(
#         (batch_norm1): BatchNorm2d(2736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2736, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-12): single_layer(
#         (batch_norm1): BatchNorm2d(2772, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2772, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-13): single_layer(
#         (batch_norm1): BatchNorm2d(2808, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2808, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-14): single_layer(
#         (batch_norm1): BatchNorm2d(2844, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2844, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-15): single_layer(
#         (batch_norm1): BatchNorm2d(2880, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2880, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-16): single_layer(
#         (batch_norm1): BatchNorm2d(2916, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2916, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-17): single_layer(
#         (batch_norm1): BatchNorm2d(2952, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2952, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-18): single_layer(
#         (batch_norm1): BatchNorm2d(2988, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2988, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-19): single_layer(
#         (batch_norm1): BatchNorm2d(3024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3024, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-20): single_layer(
#         (batch_norm1): BatchNorm2d(3060, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3060, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-21): single_layer(
#         (batch_norm1): BatchNorm2d(3096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3096, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-22): single_layer(
#         (batch_norm1): BatchNorm2d(3132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3132, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-23): single_layer(
#         (batch_norm1): BatchNorm2d(3168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3168, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-24): single_layer(
#         (batch_norm1): BatchNorm2d(3204, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3204, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-25): single_layer(
#         (batch_norm1): BatchNorm2d(3240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3240, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-26): single_layer(
#         (batch_norm1): BatchNorm2d(3276, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3276, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-27): single_layer(
#         (batch_norm1): BatchNorm2d(3312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3312, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-28): single_layer(
#         (batch_norm1): BatchNorm2d(3348, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3348, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-29): single_layer(
#         (batch_norm1): BatchNorm2d(3384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3384, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-30): single_layer(
#         (batch_norm1): BatchNorm2d(3420, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3420, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-31): single_layer(
#         (batch_norm1): BatchNorm2d(3456, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3456, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (block-32): single_layer(
#         (batch_norm1): BatchNorm2d(3492, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(3492, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (batch_norm_last_layer): BatchNorm2d(3528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_last_layer): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (flattern): flatten_layer(dim=0)
#     (linear): Linear(in_features=3528, out_features=100, bias=True)
#   )
# )
#
# Total trainable parameters in the network: 63.2821M

# %%
batch_size = 16
epochs = 20
learning_rate = 0.1
momentum = 0.9

first_run = True 
use_cuda = torch.cuda.is_available()

train_val_split = 0.9

trainloader, valloader, testloader = get_dataloader(batch_size = batch_size, train_val_split = train_val_split)
dataloaders = {'train': trainloader, 'val' : valloader, 'test': testloader}

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = momentum)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.to('cuda' if use_cuda else 'cpu')

best_val_accuracy = -math.inf

for epoch in range(epochs):

    net.train()

    batches_in_pass = len(dataloaders['train'])
    
    #Training
    training_epoch_start_time = time.time()

    loss_total = 0.0
    epoch_loss = 0.0
    
    for idx, data in enumerate(dataloaders['train']):
        
        inputs, labels = data
        inputs = inputs.to('cuda' if use_cuda else 'cpu')
        labels = labels.to('cuda' if use_cuda else 'cpu')
        
        optimizer.zero_grad()
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        loss_total += loss.item()
        
    #Validation   
    epoch_loss /= batches_in_pass

    net.eval()

    correct = 0.0
    total = 0.0
    for idx, data in enumerate(dataloaders['val']):

        inputs, labels = data
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.shape[0]
        correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * correct / total
    
    print(f'Epoch {epoch + 1} | Training Loss (Avg): {epoch_loss:.6f} | Validation Accuracy: {epoch_accuracy}% | Time elapsed: {time.time() - training_epoch_start_time:.2f}s')
    
    #Saving the model
    save_path = os.path.join(os.getcwd(), 'models', 'densenet_cifar100_k36_depth100_nobc')
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    #torch.save(net.state_dict(), os.path.join(save_path, f'epoch_{epoch}.pt'))
    
    if epoch_accuracy > best_val_accuracy:

        torch.save(net.state_dict(), os.path.join(save_path, 'best'+str(epochs)+'.pt'))
        best_val_accuracy = epoch_accuracy

print('Training Complete.')
# Out:
# Epoch 1 | Training Loss (Avg): 4.232461 | Validation Accuracy: 16.26% | Time elapsed: 3422.27s
# Epoch 2 | Training Loss (Avg): 3.371283 | Validation Accuracy: 25.2% | Time elapsed: 3426.06s
# Epoch 3 | Training Loss (Avg): 2.899351 | Validation Accuracy: 32.86% | Time elapsed: 3415.83s
# Epoch 4 | Training Loss (Avg): 2.449262 | Validation Accuracy: 40.34% | Time elapsed: 3429.46s
# Epoch 5 | Training Loss (Avg): 2.076624 | Validation Accuracy: 45.1% | Time elapsed: 3432.79s
# Epoch 6 | Training Loss (Avg): 1.773084 | Validation Accuracy: 49.66% | Time elapsed: 3432.98s
# Epoch 7 | Training Loss (Avg): 1.523944 | Validation Accuracy: 52.12% | Time elapsed: 3433.56s

# %%
#Testing
try:
    assert os.path.exists(os.path.join(save_path, 'best'+str(epochs)+'.pt'))

    net.load_state_dict(torch.load(os.path.join(save_path, 'best'+str(epochs)+'.pt')))
    net.eval()

    correct = 0.0
    total = 0.0

    with torch.no_grad():
        for idx, data in enumerate(dataloaders['test']):

            inputs, labels = data
            inputs = inputs.to('cuda' if use_cuda else 'cpu')
            labels = labels.to('cuda' if use_cuda else 'cpu')

            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)

            total += labels.shape[0]
            correct += (predicted == labels).sum().item()

        print(f'Accuracy of the model on test images: {100 * correct // total}%')
    
except:
    print('Please train the model before testing.')
# Out:
# Accuracy of the model on test images: 52.0%
